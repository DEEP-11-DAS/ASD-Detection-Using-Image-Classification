# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
data_dir = r"ASD detection using Image classification\AutismDataset\train"

# %%
batch_size = 32
img_size = (224, 224)

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=img_size,
  batch_size=batch_size)
# Out:
# Found 2540 files belonging to 2 classes.
# Using 2032 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  r"ASD detection using Image classification\AutismDataset\valid",
  seed=123,
  image_size=(img_size),
  batch_size=batch_size)
# Out:
# Found 100 files belonging to 2 classes.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['Autistic', 'Non_Autistic']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 224, 224, 3)
# (32,)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
num_classes = len(class_names)

model = Sequential([
  layers.Rescaling(1./255, input_shape=(224, 224, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 224, 224, 3)       0
#
#  conv2d (Conv2D)             (None, 224, 224, 16)      448
#
#  max_pooling2d (MaxPooling2  (None, 112, 112, 16)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 32)      4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 56, 56, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 64)        18496
#
#  max_pooling2d_2 (MaxPoolin  (None, 28, 28, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 50176)             0
#
#  dense (Dense)               (None, 128)               6422656
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 6446498 (24.59 MB)
# Trainable params: 6446498 (24.59 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
epochs=100
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/100
# 64/64 [==============================] - 272s 2s/step - loss: 0.7369 - accuracy: 0.5566 - val_loss: 0.6636 - val_accuracy: 0.6200
# Epoch 2/100
# 64/64 [==============================] - 107s 2s/step - loss: 0.6017 - accuracy: 0.6781 - val_loss: 0.5671 - val_accuracy: 0.6800
# Epoch 3/100
# 64/64 [==============================] - 111s 2s/step - loss: 0.5157 - accuracy: 0.7530 - val_loss: 0.5758 - val_accuracy: 0.6500
# Epoch 4/100
# 64/64 [==============================] - 107s 2s/step - loss: 0.4272 - accuracy: 0.8036 - val_loss: 0.5838 - val_accuracy: 0.7300
# Epoch 5/100
# 64/64 [==============================] - 107s 2s/step - loss: 0.3302 - accuracy: 0.8533 - val_loss: 0.6154 - val_accuracy: 0.7300
# Epoch 6/100
# 64/64 [==============================] - 115s 2s/step - loss: 0.2251 - accuracy: 0.9129 - val_loss: 0.6991 - val_accuracy: 0.7500
# Epoch 7/100
# 64/64 [==============================] - 109s 2s/step - loss: 0.1309 - accuracy: 0.9528 - val_loss: 0.8305 - val_accuracy: 0.6800
# Epoch 8/100
# 64/64 [==============================] - 108s 2s/step - loss: 0.0638 - accuracy: 0.9783 - val_loss: 0.9299 - val_accuracy: 0.7300
# Epoch 9/100
# 64/64 [==============================] - 111s 2s/step - loss: 0.0409 - accuracy: 0.9902 - val_loss: 1.2222 - val_accuracy: 0.6900
# Epoch 10/100
# 64/64 [==============================] - 109s 2s/step - loss: 0.0270 - accuracy: 0.9921 - val_loss: 1.0626 - val_accuracy: 0.7000
# Epoch 11/100
# 64/64 [==============================] - 108s 2s/step - loss: 0.0087 - accuracy: 0.9990 - val_loss: 1.4947 - val_accuracy: 0.7200
# Epoch 12/100
# 64/64 [==============================] - 107s 2s/step - loss: 0.0052 - accuracy: 0.9995 - val_loss: 1.5956 - val_accuracy: 0.7000
# Epoch 13/100
# 64/64 [==============================] - 112s 2s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.6398 - val_accuracy: 0.7300
# Epoch 14/100
# 64/64 [==============================] - 111s 2s/step - loss: 4.9692e-04 - accuracy: 1.0000 - val_loss: 1.7861 - val_accuracy: 0.7200
# Epoch 15/100
# 64/64 [==============================] - 105s 2s/step - loss: 2.9718e-04 - accuracy: 1.0000 - val_loss: 1.8711 - val_accuracy: 0.7100
# Epoch 16/100
# 64/64 [==============================] - 110s 2s/step - loss: 2.2813e-04 - accuracy: 1.0000 - val_loss: 1.9223 - val_accuracy: 0.7100
# Epoch 17/100
# 64/64 [==============================] - 109s 2s/step - loss: 1.8225e-04 - accuracy: 1.0000 - val_loss: 1.9986 - val_accuracy: 0.7100
# Epoch 18/100
# 64/64 [==============================] - 110s 2s/step - loss: 1.5055e-04 - accuracy: 1.0000 - val_loss: 2.0149 - val_accuracy: 0.7100
# Epoch 19/100
# 64/64 [==============================] - 110s 2s/step - loss: 1.2792e-04 - accuracy: 1.0000 - val_loss: 2.0568 - val_accuracy: 0.7100
# Epoch 20/100
# 64/64 [==============================] - 106s 2s/step - loss: 1.0896e-04 - accuracy: 1.0000 - val_loss: 2.1065 - val_accuracy: 0.7100
# Epoch 21/100
# 64/64 [==============================] - 112s 2s/step - loss: 9.5195e-05 - accuracy: 1.0000 - val_loss: 2.1287 - val_accuracy: 0.7100
# Epoch 22/100
# 64/64 [==============================] - 109s 2s/step - loss: 8.3961e-05 - accuracy: 1.0000 - val_loss: 2.1673 - val_accuracy: 0.7100
# Epoch 23/100
# 64/64 [==============================] - 110s 2s/step - loss: 7.4280e-05 - accuracy: 1.0000 - val_loss: 2.1806 - val_accuracy: 0.7100
# Epoch 24/100
# 64/64 [==============================] - 110s 2s/step - loss: 6.7373e-05 - accuracy: 1.0000 - val_loss: 2.2199 - val_accuracy: 0.7100
# Epoch 25/100
# 64/64 [==============================] - 109s 2s/step - loss: 6.0165e-05 - accuracy: 1.0000 - val_loss: 2.2480 - val_accuracy: 0.7100
# Epoch 26/100
# 64/64 [==============================] - 111s 2s/step - loss: 5.4832e-05 - accuracy: 1.0000 - val_loss: 2.2676 - val_accuracy: 0.7100
# Epoch 27/100
# 64/64 [==============================] - 108s 2s/step - loss: 4.9735e-05 - accuracy: 1.0000 - val_loss: 2.2897 - val_accuracy: 0.7100
# Epoch 28/100
# 64/64 [==============================] - 111s 2s/step - loss: 4.5395e-05 - accuracy: 1.0000 - val_loss: 2.3170 - val_accuracy: 0.7100
# Epoch 29/100
# 12/64 [====>.........................] - ETA: 1:24 - loss: 3.3363e-05 - accuracy: 1.0000

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(224,
                                  224,
                                  3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %%
model = Sequential([
  data_augmentation,
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes, name="outputs")
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ sequential_1 (Sequential)            │ ?                           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ rescaling_1 (Rescaling)              │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ outputs (Dense)                      │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
epochs = 100
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 28s 406ms/step - accuracy: 0.5152 - loss: 1.1153 - val_accuracy: 0.6700 - val_loss: 0.6292
# Epoch 2/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 25s 395ms/step - accuracy: 0.6269 - loss: 0.6510 - val_accuracy: 0.6500 - val_loss: 0.5988
# Epoch 3/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 25s 390ms/step - accuracy: 0.6710 - loss: 0.6156 - val_accuracy: 0.6800 - val_loss: 0.5788
# Epoch 4/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 25s 398ms/step - accuracy: 0.6985 - loss: 0.5808 - val_accuracy: 0.6900 - val_loss: 0.5648
# Epoch 5/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 25s 396ms/step - accuracy: 0.6740 - loss: 0.6058 - val_accuracy: 0.6900 - val_loss: 0.5516
# Epoch 6/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 25s 395ms/step - accuracy: 0.7143 - loss: 0.5576 - val_accuracy: 0.7600 - val_loss: 0.4897
# Epoch 7/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 26s 401ms/step - accuracy: 0.7072 - loss: 0.5511 - val_accuracy: 0.7700 - val_loss: 0.5049
# Epoch 8/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 25s 388ms/step - accuracy: 0.7197 - loss: 0.5361 - val_accuracy: 0.7200 - val_loss: 0.5088
# Epoch 9/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 25s 391ms/step - accuracy: 0.7341 - loss: 0.5342 - val_accuracy: 0.7100 - val_loss: 0.5616
# Epoch 10/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 25s 395ms/step - accuracy: 0.7321 - loss: 0.5101 - val_accuracy: 0.7400 - val_loss: 0.5250
# Epoch 11/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 25s 388ms/step - accuracy: 0.7273 - loss: 0.5138 - val_accuracy: 0.7100 - val_loss: 0.5114
# Epoch 12/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 27s 423ms/step - accuracy: 0.7437 - loss: 0.5046 - val_accuracy: 0.7300 - val_loss: 0.5093
# Epoch 13/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 28s 440ms/step - accuracy: 0.7520 - loss: 0.5049 - val_accuracy: 0.6800 - val_loss: 0.5972
# Epoch 14/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 27s 417ms/step - accuracy: 0.7599 - loss: 0.4801 - val_accuracy: 0.6900 - val_loss: 0.5837
# Epoch 15/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 27s 415ms/step - accuracy: 0.7501 - loss: 0.4900 - val_accuracy: 0.6900 - val_loss: 0.6032

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
img = tf.keras.utils.load_img(
   r"ASD detection using Image classification\AutismDataset\test\Autistic.100.jpg", target_size=(224,224)
)

plt.imshow(img)
plt.axis('off')
plt.show()

img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# This image most likely belongs to Non_Autistic with a 86.79 percent confidence.
